# %%
import os
from tqdm import tqdm
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.io import wavfile
from python_speech_features import mfcc, logfbank
import librosa

def plot_signals(signals):
    fig, axes = plt.subplots(nrows=2, ncols=5, sharex=False,
                             sharey=True, figsize=(20,5))
    fig.suptitle('Time Series', size=16)
    i = 0
    for x in range(2):
        for y in range(5):
            axes[x,y].set_title(list(signals.keys())[i])
            axes[x,y].plot(list(signals.values())[i])
            axes[x,y].get_xaxis().set_visible(False)
            axes[x,y].get_yaxis().set_visible(False)
            i += 1

def plot_fft(fft):
    fig, axes = plt.subplots(nrows=2, ncols=5, sharex=False,
                             sharey=True, figsize=(20,5))
    fig.suptitle('Fourier Transforms', size=16)
    i = 0
    for x in range(2):
        for y in range(5):
            data = list(fft.values())[i]
            Y, freq = data[0], data[1]
            axes[x,y].set_title(list(fft.keys())[i])
            axes[x,y].plot(freq, Y)
            axes[x,y].get_xaxis().set_visible(False)
            axes[x,y].get_yaxis().set_visible(False)
            i += 1

def plot_fbank(fbank):
    fig, axes = plt.subplots(nrows=2, ncols=5, sharex=False,
                             sharey=True, figsize=(20,5))
    fig.suptitle('Filter Bank Coefficients', size=16)
    i = 0
    for x in range(2):
        for y in range(5):
            axes[x,y].set_title(list(fbank.keys())[i])
            axes[x,y].imshow(list(fbank.values())[i],
                    cmap='hot', interpolation='nearest')
            axes[x,y].get_xaxis().set_visible(False)
            axes[x,y].get_yaxis().set_visible(False)
            i += 1

def plot_mfccs(mfccs):
    fig, axes = plt.subplots(nrows=2, ncols=5, sharex=False,
                             sharey=True, figsize=(20,5))
    fig.suptitle('Mel Frequency Cepstrum Coefficients', size=16)
    i = 0
    for x in range(2):
        for y in range(5):
            axes[x,y].set_title(list(mfccs.keys())[i])
            axes[x,y].imshow(list(mfccs.values())[i],
                    cmap='hot', interpolation='nearest')
            axes[x,y].get_xaxis().set_visible(False)
            axes[x,y].get_yaxis().set_visible(False)
            i += 1
            
def calc_fft(y, rate):
    n = len(y)
    freq = np.fft.rfftfreq(n, d=1/rate)
    Y = abs(np.fft.rfft(y)/n)
    return (Y, freq)

df = pd.read_csv('language.csv')
df.set_index('fname', inplace=True)

for f in df.index:
    rate, signal = wavfile.read('wavefiles/'+f)
    df.at[f, 'length'] = signal.shape[0]/rate

# %%
df
# Out:
#                                    label  length
# fname
# common_voice_ga-IE_17358884.wav    Irish   6.504
# common_voice_ga-IE_17358885.wav    Irish   4.416
# common_voice_ga-IE_17358886.wav    Irish   3.144
# common_voice_ga-IE_17358896.wav    Irish   5.064
# common_voice_ga-IE_17358897.wav    Irish   2.544
# common_voice_ga-IE_17358898.wav    Irish   5.184
# common_voice_ga-IE_17358902.wav    Irish   2.904
# common_voice_ga-IE_17358903.wav    Irish   3.504
# common_voice_ga-IE_17358904.wav    Irish   3.744
# common_voice_ga-IE_17358905.wav    Irish   4.704
# common_voice_ga-IE_17358906.wav    Irish   2.784
# common_voice_ga-IE_17358907.wav    Irish   4.704
# common_voice_ga-IE_17358926.wav    Irish   2.736
# common_voice_ga-IE_17358927.wav    Irish   2.256
# common_voice_ga-IE_17358928.wav    Irish   3.264
# common_voice_ga-IE_17359842.wav    Irish   3.864
# common_voice_ga-IE_17359843.wav    Irish   3.144
# common_voice_ga-IE_17359844.wav    Irish   3.144
# common_voice_ga-IE_17359845.wav    Irish   3.696
# common_voice_ga-IE_17359846.wav    Irish   3.384
# common_voice_ga-IE_17359847.wav    Irish   1.944
# common_voice_ga-IE_17359848.wav    Irish   4.104
# common_voice_ga-IE_17359849.wav    Irish   2.544
# common_voice_ga-IE_17359850.wav    Irish   3.024
# common_voice_ga-IE_17359851.wav    Irish   3.936
# common_voice_ga-IE_17359852.wav    Irish   3.264
# common_voice_ga-IE_17359853.wav    Irish   3.144
# common_voice_ga-IE_17360280.wav    Irish   5.064
# common_voice_ga-IE_17360281.wav    Irish   6.336
# common_voice_ga-IE_17360282.wav    Irish   3.456
# ...                                  ...     ...
# common_voice_sv-SE_18774290.wav  Swedish   5.280
# common_voice_sv-SE_18774291.wav  Swedish   3.408
# common_voice_sv-SE_18774292.wav  Swedish   2.592
# common_voice_sv-SE_18774293.wav  Swedish   3.192
# common_voice_sv-SE_18774294.wav  Swedish   2.544
# common_voice_sv-SE_18774295.wav  Swedish   3.240
# common_voice_sv-SE_18774296.wav  Swedish   5.040
# common_voice_sv-SE_18774297.wav  Swedish   2.376
# common_voice_sv-SE_18774303.wav  Swedish   2.952
# common_voice_sv-SE_18774304.wav  Swedish   4.392
# common_voice_sv-SE_18774305.wav  Swedish   2.280
# common_voice_sv-SE_18774306.wav  Swedish   2.376
# common_voice_sv-SE_18774307.wav  Swedish   3.096
# common_voice_sv-SE_18774313.wav  Swedish   3.744
# common_voice_sv-SE_18774314.wav  Swedish   2.592
# common_voice_sv-SE_18774315.wav  Swedish   2.784
# common_voice_sv-SE_18774316.wav  Swedish   1.800
# common_voice_sv-SE_18774317.wav  Swedish   2.424
# common_voice_sv-SE_18774318.wav  Swedish   2.904
# common_voice_sv-SE_18774319.wav  Swedish   3.792
# common_voice_sv-SE_18774320.wav  Swedish   2.496
# common_voice_sv-SE_18774321.wav  Swedish   3.408
# common_voice_sv-SE_18774322.wav  Swedish   3.912
# common_voice_sv-SE_18774328.wav  Swedish   5.640
# HindiPN_3_1_3_14.wav               Hindi   7.104
# HindiPN_3_1_3_16.wav               Hindi   8.448
# HindiPN_3_1_3_17.wav               Hindi   7.056
# HindiPN_3_1_3_19.wav               Hindi  10.368
# HindiPN_3_1_3_7.wav                Hindi   8.016
# HindiPN_3_1_3_8.wav                Hindi   7.728
#
# [4006 rows x 2 columns]

# %%
classes = list(np.unique(df.label))
class_distribution = df.groupby(['label'])['length'].mean()

# %%
class_distribution
# Out:
# label
# Hindi      8.120000
# Irish      3.145464
# Swedish    3.065640
# Name: length, dtype: float64

# %%
fig, ax = plt.subplots()
ax.set_title('Class Distribution', y=1.08)
ax.pie(class_distribution, labels=class_distribution.index, autopct='%1.1f%%', shadow=False, startangle=90)
ax.axis('equal')
plt.show()
df.reset_index(inplace=True)

# %%
signals = {}
fft = {}
fbank = {}
mfccs = {}

for c in classes:
    wav_file = df[df.label == c].iloc[0,0]
    signal, rate = librosa.load('wavefiles/'+wav_file, sr=44100)
    signals[c] = signal
    fft[c] = calc_fft(signal, rate)
    
    bank = logfbank(signal[:rate], rate, nfilt=26, nfft=1103).T
    fbank[c]  = bank
    mel = mfcc(signal[:rate], rate, numcep=13, nfilt=26, nfft=1103).T
    mfccs[c] = mel
    
plot_signals(signals)
plt.show()

plot_fft(fft)
plt.show()

plot_fbank(fbank)
plt.show()

plot_mfccs(mfccs)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-115-e6600c7ab18e> in <module>()
#      15     mfccs[c] = mel
#      16
# ---> 17 plot_signals(signals)
#      18 plt.show()
#      19
#
# <ipython-input-110-0955b6621fb6> in plot_signals(signals)
#      15     for x in range(2):
#      16         for y in range(5):
# ---> 17             axes[x,y].set_title(list(signals.keys())[i])
#      18             axes[x,y].plot(list(signals.values())[i])
#      19             axes[x,y].get_xaxis().set_visible(False)
#
# IndexError: list index out of range
